# %% [markdown]
# # Set

# %% [markdown]
# ## // Khởi tạo

# %%
// cách 1
Set<Student> setStudent;

// cách 2
Student *setStudent1 = new Student[10];
Set<Student> setStudent2(setStudent1, 10);

// cách 3
Set<Student> setStudent1 ;
Set<Student> setStudent2(setStudent1);

# %% [markdown]
# ## // toán tử

# %%
// And : Giao của 2 set tập hợp
setStudent3 = setStudent1 & setStudent2;

# %%
// Or : Hợp của 2 set tập hợp
setStudent3 = setStudent1 | setStudent2;

# %%
// Xor = Or - And
setStudent3 = setStudent1 ^ setStudent2;

# %%
// phép trừ 
setStudent3 = setStudent1 - setStudent2;

# %% [markdown]
# ## // phương thức thêm phần tử

# %%
setStudent1.insert(student1);

# %% [markdown]
# ## // phương thức xóa phần tử

# %%
// xóa 1 phần tử
setStudent1.erase(student1);

// xóa phần tử ở vị trí 10
setStudent1.erase(setStudent1.begin()+10)

// xóa phần tử ở vị trí -10
setStudent1.erase(setStudent1.end()-10)

// xóa mọi phần tử 
setStudent1.erase(setStudent1.begin(), setStudent1.end())

# %% [markdown]
# ## // phương thức tìm kiếm một phần tử

# %%
Set<Student>::iterator index1 = setStudent1.find(student1);

cout << index1 << endl;
