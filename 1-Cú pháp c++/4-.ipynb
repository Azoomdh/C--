# %% [markdown]
# # https://cplusplus.com/doc/tutorial/
# ____

# %% [markdown]
# # khai báo mảng

# %%
int a[5];

int a[5] = { 16, 2, 77, 40, 12071 };

int a[5] = { 10, 20, 30 }; // a[3] và a[4] = 0

int a[5] = { }; // mọi phần tử đều bằng 0

int a[] = { 16, 2, 77, 40, 12071 };

# %% [markdown]
# # get/set giá trị của 1 mảng

# %%
x = a[2];

a[2] = 75;

# %% [markdown]
# # mảng nhiều chiều

# %%
int a[3][5];

// Mảng đa chiều không bị giới hạn ở hai chỉ số (tức là hai chiều). Chúng có thể chứa bao nhiêu chỉ số tùy ý. Tuy nhiên, hãy cẩn thận: dung lượng bộ nhớ cần thiết cho một mảng tăng theo cấp số nhân với mỗi chiều. Ví dụ:
// char century [100][365][24][60][60];

# %%
// cảm giác không cần học những phần này
