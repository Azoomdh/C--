# %% [markdown]
# # toán tử liên quan con trỏ

# %%
Int a=5; 
*a = giá trị tại ô nhớ 5 trên Ram

# %%
Int a=5
&a = địa chỉ của a

# %%
Student x = new Student()
x.name = giá trị name của object x

# %%
Student x = new Student()

// a là &x, &x là địa chỉ trên Ram của x
Student *a = &x 

a->name = giá trị name của a
(*a).name = giá trị name của a

# %%
Student x[] = new Vector<Student>()

x[n] = giá trị thứ n+1
